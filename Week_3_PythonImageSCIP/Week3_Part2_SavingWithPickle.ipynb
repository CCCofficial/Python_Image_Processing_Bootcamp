# %%
#import glob
from google.colab import drive
import matplotlib.pyplot as plt
from IPython import display
from time import sleep
import cv2
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
from google.colab import files
testList=[1,2,3,4]

print('saving testList',testList)
pick_insert = open('drive/My Drive/testList.pickle','wb')
pickle.dump(testList, pick_insert)
pick_insert.close()

pick_read = open('drive/My Drive/testList.pickle','rb')
testList = pickle.load(pick_read)
pick_read.close()
print('retrieved testList',testList)
# Out:
# saving testList [1, 2, 3, 4]
# retrieved testList [1, 2, 3, 4]
